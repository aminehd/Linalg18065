# %% [markdown]
# # Vectors and Matrices
#
# **Date**: October 27, 2025
#
# **Key Concepts**:
# - Vector and matrix operations (addition, scalar multiplication)
# - Dot products
# - Matrix-vector and matrix-matrix multiplication
# - Vector norms (L1, L2)
#
# **References**:
# - Gilbert Strang, Linear Algebra and Learning from Data, Chapter I.1

# %%
# Standard imports
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la

# %matplotlib inline
